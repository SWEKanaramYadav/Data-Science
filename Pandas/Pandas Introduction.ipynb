# %%
import numpy as np
import pandas as pd

# %%
dict1 = {
    "Name":['kanaram', 'pintu','mukesh','chiku'],
    "Marks":[99,66,77,88],
    "City":['Jaipur','ajmer','kota','jodhpur'],
}

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#       Name  Marks     City
# 0  kanaram     99   Jaipur
# 1    pintu     66    ajmer
# 2   mukesh     77     kota
# 3    chiku     88  jodhpur

# %% [markdown]
# ###### Create CSV file for result data

# %%
df.to_csv('student_details.csv')     #with index

# %%
df.to_csv('student_indexFalse.csv', index=False)    #index false

# %%
df.head(2)   #show first two row
# Out:
#       Name  Marks    City
# 0  kanaram     99  Jaipur
# 1    pintu     66   ajmer

# %%
df.tail(2)    #show last two row
# Out:
#      Name  Marks     City
# 2  mukesh     77     kota
# 3   chiku     88  jodhpur

# %%
df.describe()        #calculate min, max, mean, std,count, 75%, 50%, 25%
# Out:
#            Marks
# count   4.000000
# mean   82.500000
# std    14.200939
# min    66.000000
# 25%    74.250000
# 50%    82.500000
# 75%    90.750000
# max    99.000000

# %%
Train = pd.read_csv('ram.csv', index = ['TR1','TR2','TR3','TR4','TR5'])    #read CSV File
# Out:
# -------------------------------------------------------------
# TypeError                   Traceback (most recent call last)
# <ipython-input-41-2793418b3962> in <module>
# ----> 1 Train = pd.read_csv('ram.csv', index = ['TR1','TR2','TR3','TR4','TR5'])    #read CSV File
#
# TypeError: parser_f() got an unexpected keyword argument 'index'

# %%
Train
# Out:
#    Train No  Train Speed From City To City
# 0    134234           99    Jaipur   ajmer
# 1    245223           66     ajmer  Jaipur
# 2      2525          107      kota  Jaipur
# 3     25252           88   jodhpur   ajmer
# 4     56363           99     ajmer    kota

# %%
Train['Train Speed'][0] = 110
# Out:
# <ipython-input-12-823ff74701f3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Train['Train Speed'][0] = 110

# %%
Train
# Out:
#    Train No  Train Speed From City To City
# 0    134234          110    Jaipur   ajmer
# 1    245223           66     ajmer  Jaipur
# 2      2525          107      kota  Jaipur
# 3     25252           88   jodhpur   ajmer
# 4     56363           99     ajmer    kota

# %%
Train.to_csv('ram1.csv',)

# %%
Train.loc[[1,2,3],["Train No","To City"]]
# Out:
# -------------------------------------------------------------
# KeyError                    Traceback (most recent call last)
# <ipython-input-55-f9b6d5722a97> in <module>
# ----> 1 Train.loc[[1,2,3],["Train No","To City"]]
#
# c:\users\kanar\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1760                 except (KeyError, IndexError, AttributeError):
#    1761                     pass
# -> 1762             return self._getitem_tuple(key)
#    1763         else:
#    1764             # we by definition only have the 0th axis
#
# c:\users\kanar\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1279         # ugly hack for GH #836
#    1280         if self._multi_take_opportunity(tup):
# -> 1281             return self._multi_take(tup)
#    1282
#    1283         # no shortcut needed
#
# ...

# %%
Train.index = ['TR1','TR2','TR3','TR4','TR5']    #change Index

# %%
Train
# Out:
#      Train No  Train Speed From City To City
# TR1    134234          110    Jaipur   ajmer
# TR2    245223           66     ajmer  Jaipur
# TR3      2525          107      kota  Jaipur
# TR4     25252           88   jodhpur   ajmer
# TR5     56363           99     ajmer    kota

# %%
Train. loc[['TR1','TR2','TR3','TR4','TR5'],["Train No","To City"]]
# Out:
#      Train No To City
# TR1    134234   ajmer
# TR2    245223  Jaipur
# TR3      2525  Jaipur
# TR4     25252   ajmer
# TR5     56363    kota

# %%
ser = pd.Series(np.random.rand(100))  #series

# %%
ser
# Out:
# 0     0.789183
# 1     0.381915
# 2     0.707886
# 3     0.331359
# 4     0.592307
#         ...
# 95    0.883807
# 96    0.405979
# 97    0.407419
# 98    0.291325
# 99    0.246163
# Length: 100, dtype: float64

# %%
type(ser)     #series a data structure in pandas
# Out:
# pandas.core.series.Series

# %%
newdf = pd.DataFrame(np.random.rand(500,5), index=np.arange(500))

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0